# %%
import pandas as pd

#df = pd.read_csv('/Users/wassim/project1_csv_sql/data/raw/BMW_Car_Sales_Classification.csv')
data_path = '/kaggle/input/bmw-car-sales-dataset/BMW_Car_Sales_Classification.csv'
try:
    df = pd.read_csv(data_path, encoding='ascii')
    print('Data loaded successfully.')
except Exception as e:
    print('Error loading data: ', e)
print("First 5 rows ",df.head())
print("Table information ",df.info())
print("Shape of table is :" ,df.shape)
# Out:
# Error loading data:  [Errno 2] No such file or directory: '/kaggle/input/bmw-car-sales-dataset/BMW_Car_Sales_Classification.csv'
# First 5 rows        Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# ...

# %%
df.isnull().sum()
# Out:
# Model                   0
# Year                    0
# Region                  0
# Color                   0
# Fuel_Type               0
# Transmission            0
# Engine_Size_L           0
# Mileage_KM              0
# Price_USD               0
# Sales_Volume            0
# Sales_Classification    0
# dtype: int64

# %%
df.dtypes
# Out:
# Model                    object
# Year                      int64
# Region                   object
# Color                    object
# Fuel_Type                object
# Transmission             object
# Engine_Size_L           float64
# Mileage_KM                int64
# Price_USD                 int64
# Sales_Volume              int64
# Sales_Classification     object
# dtype: object

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#                Year  Engine_Size_L     Mileage_KM      Price_USD  Sales_Volume
# count  50000.000000   50000.000000   50000.000000   50000.000000  50000.000000
# mean    2017.015700       3.247180  100307.203140   75034.600900   5067.514680
# std        4.324459       1.009078   57941.509344   25998.248882   2856.767125
# min     2010.000000       1.500000       3.000000   30000.000000    100.000000
# 25%     2013.000000       2.400000   50178.000000   52434.750000   2588.000000
# 50%     2017.000000       3.200000  100388.500000   75011.500000   5087.000000
# 75%     2021.000000       4.100000  150630.250000   97628.250000   7537.250000
# max     2024.000000       5.000000  199996.000000  119998.000000   9999.000000

# %%
df.describe().T.plot.barh(figsize=(10, 6))
df.describe().T.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.dropna(inplace=True)
df['Year'] = df['Year'].astype(int)

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
for col in numeric_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()
